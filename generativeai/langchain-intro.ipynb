# %% [markdown]
# # Langchain Learning

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.15

# %%
import os 
from dotenv import load_dotenv

load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("llama-3.1-8b-instant", model_provider="groq")
model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x760a7a3fa900>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x760a7a3f8830>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
# first gen ai agent
response=model.invoke("Write a 100 words note on ai impact on swe jobs")
print(response.content)
# Out:
# **The Impact of AI on Software Jobs**
#
# Artificial intelligence (AI) is increasingly transforming the software industry, both positively and negatively. On the one hand, AI is augmenting human capabilities, automating repetitive tasks, and improving software development velocity. This shift enables developers to focus on high-level tasks, driving innovation and efficiency. However, AI also poses a threat to some software jobs, particularly those involving data entry, testing, and maintenance. As AI-powered tools become more prevalent, companies may reduce their workforce, potentially displacing certain roles. To adapt, software professionals must develop skills that complement AI, such as AI development, strategy, and ethics.

# %%
for chunk in model.stream("whats 2s table till 10 times "):
    print(chunk.text, end=" ")
# Out:
#  Here 's  the  table  of   2  up  to   10  times :
#
#  2  x   1  =   2
#  2  x   2  =   4
#  2  x   3  =   6
#  2  x   4  =   8
#  2  x   5  =   10
#  2  x   6  =   12
#  2  x   7  =   14
#  2  x   8  =   16
#  2  x   9  =   18
#  2  x   10  =   20
